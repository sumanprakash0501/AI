# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"Open AI Key exisits and begins with {openai_api_key[:8]}")
else:
    print("Open AI Key not exist. Please add a valid open AI Key")
# Out:
# Open AI Key exisits and begins with sk-proj-

# %%
from openai import OpenAI

# %%
openai_client = OpenAI()

# %%
query= "What is 2+2"
messages = [{"role":"user", "content":query}]

# %%
from IPython.display import Markdown, display
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages= messages
)
#display(Markdown(response))
print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
query = "Please provide a hard challenging question to analyze someone's IQ. Please provide question only"
message = [{"role":"user", "content":query}]
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages= message
)
question = response.choices[0].message.content
display(Markdown(question))
# Out:
# If a plane crashes on the border of the United States and Canada, where do they bury the survivors?

# %%
message=[{"role":"user", "content":question}]
response=openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=message
)
answer=response.choices[0].message.content
print(answer)
display(Markdown(answer))
# Out:
# You don't bury survivors! This is a classic riddle or joke. The point is that survivors are those who lived through the crash, so there would be no need to bury them.
# You don't bury survivors! This is a classic riddle or joke. The point is that survivors are those who lived through the crash, so there would be no need to bury them.
